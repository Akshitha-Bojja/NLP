# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-Bojja/NLP/blob/main/Assignment-03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implement Word Embeddings on following text words = ['king', 'queen', 'man', 'woman', 'paris', 'france', 'london', 'england']. [CO1]

# %%
# Importing necessary libraries
import gensim.downloader as api

# Load pre-trained word vectors (Word Embeddings)
word_vectors = api.load("glove-wiki-gigaword-100")  # Using GloVe embeddings with 100-dimensional vectors

# List of words to explore
words = ['king', 'queen', 'man', 'woman', 'paris', 'france', 'london', 'england']

# Exploring Word Embeddings
def explore_embeddings(word_list):
    for word in word_list:
            if word in word_vectors:
                        print(f"Words most similar to '{word}':")
                        similar_words = word_vectors.most_similar(word)
                        for similar_word, similarity in similar_words:
                            print(f"{similar_word}: {similarity:.4f}")
                        print()  # For better readability between words
            else:
                        print(f"'{word}' not found in the vocabulary.")

# Example usage
explore_embeddings(words)
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# Words most similar to 'king':
# prince: 0.7682
# queen: 0.7508
# son: 0.7021
# brother: 0.6986
# monarch: 0.6978
# throne: 0.6920
# kingdom: 0.6811
# father: 0.6802
# emperor: 0.6713
# ii: 0.6676
#
# Words most similar to 'queen':
# princess: 0.7947
# king: 0.7508
# elizabeth: 0.7356
# royal: 0.7065
# lady: 0.7045
# victoria: 0.6854
# monarch: 0.6683
# crown: 0.6681
# prince: 0.6641
# consort: 0.6571
#
# Words most similar to 'man':
# woman: 0.8323
# boy: 0.7915
# one: 0.7789
# person: 0.7527
# another: 0.7522
# old: 0.7409
# life: 0.7372
# father: 0.7370
# turned: 0.7348
# who: 0.7346
#
# Words most similar to 'woman':
# girl: 0.8473
# man: 0.8323
# mother: 0.8276
# boy: 0.7721
# she: 0.7632
# child: 0.7602
# wife: 0.7505
# her: 0.7446
# herself: 0.7426
# daughter: 0.7264
#
# Words most similar to 'paris':
# prohertrib: 0.7994
# france: 0.7482
# london: 0.7338
# brussels: 0.7038
# french: 0.6931
# rome: 0.6879
# amsterdam: 0.6758
# vienna: 0.6608
# berlin: 0.6586
# madrid: 0.6284
#
# Words most similar to 'france':
# belgium: 0.8076
# french: 0.8004
# britain: 0.7951
# spain: 0.7557
# paris: 0.7482
# germany: 0.7294
# italy: 0.7164
# europe: 0.7097
# netherlands: 0.7073
# luxembourg: 0.6757
#
# Words most similar to 'london':
# sydney: 0.7536
# paris: 0.7338
# melbourne: 0.7044
# york: 0.6945
# dublin: 0.6913
# edinburgh: 0.6831
# prohertrib: 0.6786
# glasgow: 0.6696
# british: 0.6597
# britain: 0.6527
#
# Words most similar to 'england':
# scotland: 0.8307
# wales: 0.8128
# australia: 0.7859
# ireland: 0.7624
# indies: 0.7226
# manchester: 0.7210
# zealand: 0.7200
# cricket: 0.7174
# newcastle: 0.6888
# leeds: 0.6885

# %% [markdown]
# Implement Word Embeddings using PCA (Principal Component Analysis) on following text) words = ['king', 'queen', 'man', 'woman', 'paris', 'france', 'london', 'england'].

# %%
import gensim.downloader as api
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load pre-trained word vectors (Word Embeddings)
word_vectors = api.load("glove-wiki-gigaword-100")  # Using GloVe embeddings with 100-dimensional vectors

# List of words to explore
words = ['king', 'queen', 'man', 'woman', 'paris', 'france', 'london', 'england']

# Extract vectors for the words
word_vecs = [word_vectors[word] for word in words if word in word_vectors]

# Apply PCA to reduce dimensionality to 2D
pca = PCA(n_components=2)
result = pca.fit_transform(word_vecs)

# Plotting
plt.figure(figsize=(10, 8))
plt.scatter(result[:, 0], result[:, 1], c='red')

for i, word in enumerate(words):
    if word in word_vectors:
            plt.text(result[i, 0], result[i, 1], word, fontsize=12)

            plt.title('2D PCA of Word Embeddings')
            plt.xlabel('Principal Component 1')
            plt.ylabel('Principal Component 2')
            plt.grid(True)
            plt.show()

# %% [markdown]
# Execute Dependency Parsing on any text or on following text [CO1] The quick brown fox jumps over the lazy dog

# %%
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Text to parse
text = "The quick brown fox jumps over the lazy dog"

# Process the text with spaCy
doc = nlp(text)

# Print dependency parsing results
print("Token\tLemma\tPOS\tDependency\tHead")
print("="*50)
for token in doc:
    print(f"{token.text}\t{token.lemma_}\t{token.pos_}\t{token.dep_}\t{token.head.text}")
# Out:
# Token	Lemma	POS	Dependency	Head
# ==================================================
# The	the	DET	det	fox
# quick	quick	ADJ	amod	fox
# brown	brown	ADJ	amod	fox
# fox	fox	NOUN	nsubj	jumps
# jumps	jump	VERB	ROOT	jumps
# over	over	ADP	prep	jumps
# the	the	DET	det	dog
# lazy	lazy	ADJ	amod	dog
# dog	dog	NOUN	pobj	over
